# %%
import re
import os
import sys
import json
import string
from pathlib import Path 
import csv

import pandas as pd
from collections import Counter
import tweepy
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

from textblob import TextBlob

import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
nltk.download('punkt')

import preprocessor as p

# to view all columns
pd.set_option("display.max.columns", None)

def get_twauth():
    path = Path('.') / '.env/twitter_keys.json'
    twitter_auth = json.load(open(path))
    return twitter_auth

tw_auth = get_twauth()

class tweetsearch():
    '''
    This is a basic class to search and download twitter data.
    You can build up on it to extend the functionalities for more 
    sophisticated analysis
    '''
    def __init__(self, cols=None,auth=None):
        #
        if not cols is None:
            self.cols = cols
        else:
            self.cols = ['id', 'created_at', 'source', 'original_text','clean_text', 
                    'sentiment','polarity','subjectivity', 'lang',
                    'favorite_count', 'retweet_count', 'original_author', 'screen_count',
                    'followers_count','friends_count','possibly_sensitive', 'hashtags',
                    'user_mentions', 'place', 'place_coord_boundaries']
            
        if auth is None:
            
            #Variables that contains the user credentials to access Twitter API 
            consumer_key = tw_auth['TWITTER_CONSUMER_KEY']
            consumer_secret = tw_auth['TWITTER_CONSUMER_SECRET']
            access_token = tw_auth['TWITTER_ACCESS_TOKEN']
            access_token_secret = tw_auth['TWITTER_ACCESS_TOKEN_SECRET']
            


            #This handles Twitter authetification and the connection to Twitter Streaming API
            auth = OAuthHandler(consumer_key, consumer_secret)
            auth.set_access_token(access_token, access_token_secret)
            

        #            
        self.auth = auth
        self.api = tweepy.API(auth, wait_on_rate_limit=True) 
        self.filtered_tweet = ''
            

    def clean_tweets(self, twitter_text):

        #use pre processor
        tweet = p.clean(twitter_text)

         #HappyEmoticons
        emoticons_happy = set([
            ':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
            ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
            '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
            'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',
            '<3'
            ])

        # Sad Emoticons
        emoticons_sad = set([
            ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
            ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
            ':c', ':{', '>:\\', ';('
            ])

        #Emoji patterns
        emoji_pattern = re.compile("["
                 u"\U0001F600-\U0001F64F"  # emoticons
                 u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                 u"\U0001F680-\U0001F6FF"  # transport & map symbols
                 u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                 u"\U00002702-\U000027B0"
                 u"\U000024C2-\U0001F251"
                 "]+", flags=re.UNICODE)

        #combine sad and happy emoticons
        emoticons = emoticons_happy.union(emoticons_sad)

        stop_words = set(stopwords.words('english'))
        word_tokens = nltk.word_tokenize(tweet)
        #after tweepy preprocessing the colon symbol left remain after      
        #removing mentions
        tweet = re.sub(r':', '', tweet)
        tweet = re.sub(r'‚Ä¶', '', tweet)

        #replace consecutive non-ASCII characters with a space
        tweet = re.sub(r'[^\x00-\x7F]+',' ', tweet)

        #remove emojis from tweet
        tweet = emoji_pattern.sub(r'', tweet)

        #filter using NLTK library append it to a string
        filtered_tweet = [w for w in word_tokens if not w in stop_words]

        #looping through conditions
        filtered_tweet = []    
        for w in word_tokens:
        #check tokens against stop words , emoticons and punctuations
            if w not in stop_words and w not in emoticons and w not in string.punctuation:
                filtered_tweet.append(w)

        return ' '.join(filtered_tweet)            

    def get_tweets(self, keyword, csvfile=None):
        
        
        df = pd.DataFrame(columns=self.cols)
        

        #page attribute in tweepy.cursor and iteration
        for page in tweepy.Cursor(self.api.search, q=keyword, count=100, include_rts=False, lang='en', tweet_mode='extended').pages():

            # the you receive from the Twitter API is in a JSON format and has quite an amount of information attached
            for status in page:
                
                new_entry = []
                status = status._json
                
                #if this tweet is a retweet update retweet count
                if status['created_at'] in df['created_at'].values:
                    i = df.loc[df['created_at'] == status['created_at']].index[0]
                    #
                    cond1 = status['favorite_count'] != df.at[i, 'favorite_count']
                    cond2 = status['retweet_count'] != df.at[i, 'retweet_count']
                    if cond1 or cond2:
                        df.at[i, 'favorite_count'] = status['favorite_count']
                        df.at[i, 'retweet_count'] = status['retweet_count']
                    continue

                #calculate sentiment
                filtered_tweet = self.clean_tweets(status['full_text'])
                blob = TextBlob(filtered_tweet)
                Sentiment = blob.sentiment     
                polarity = Sentiment.polarity
                subjectivity = Sentiment.subjectivity

                new_entry += [status['id'], status['created_at'],
                              status['source'], status['full_text'], filtered_tweet, 
                              Sentiment,polarity,subjectivity, status['lang'],
                              status['favorite_count'], status['retweet_count']]

                new_entry.append(status['user']['screen_name'])
                new_entry.append(status['user']['statuses_count'])
                new_entry.append(status['user']['followers_count'])
                new_entry.append(status['user']['friends_count'])
                

                try:
                    is_sensitive = status['possibly_sensitive']
                except KeyError:
                    is_sensitive = None

                new_entry.append(is_sensitive)

                hashtags = ", ".join([hashtag_item['text'] for hashtag_item in status['entities']['hashtags']])
                new_entry.append(hashtags) #append the hashtags

                #
                mentions = ", ".join([mention['screen_name'] for mention in status['entities']['user_mentions']])
                new_entry.append(mentions) #append the user mentions

                try:
                    xyz = status['place']['bounding_box']['coordinates']
                    coordinates = [coord for loc in xyz for coord in loc]
                except TypeError:
                    coordinates = None
                #
                new_entry.append(coordinates)

                try:
                    location = status['user']['location']
                except TypeError:
                    location = ''
                #
                new_entry.append(location)

                #now append a row to the dataframe
                single_tweet_df = pd.DataFrame([new_entry], columns=self.cols)
                df = df.append(single_tweet_df, ignore_index=True)

        #
        df['timestamp'] = df.created_at.map(pd.Timestamp)
        df = df.sort_values('timestamp').set_index('timestamp')
        df = df.drop('id',axis=1)
#         print(df.shape[0]) 
        
        if not csvfile is None:
            #save it to file
            df.to_csv(csvfile,mode='a', index=True, encoding="utf-8")
#             print(df.shape[0])
            

        return df
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/abubakar/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/abubakar/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def user_tweets(all_users):
    for user in all_users:
        try:
            ts = tweetsearch()
            df = ts.get_timeline(user, csvfile='twitter_data.csv')
            print(user)
        except tweepy.TweepError as e:
            print(e)
            continue

# %%
additional = ['Mobilemoney','Cashless','Fintech','Financial Technology', 'StartUp Africa']
list_of_places_one = ['Kenya','Nairobi','Kisumu','Mombasa', 'Ghana', 'Egypt']
list_of_places_two = ['Nigeria','Lagos', 'Abuja', "Kaduna", "Kano"]
list_of_places_three = ['South Africa','Johannesburg','Cape Town']
all_list_of_places = [list_of_places_one, list_of_places_two, list_of_places_three]

# %%
list_of_keywords = ['Insecurity','Kidnapping','Drugs','Armed Robbery','Robbery','Rape','Illegal Assult',
                    'Terrorism','Banditry','Bandits','Insurgency','Theft','Bulgary','Murder','Killing Innocent','Ritual Killing','Woobly Security',
                    'Abduct','Laugage Snatch','Bad Governance','Cost of Security','Theifs','Bad Leaders', 'Corruption','Injustice',
                    'Ransom','Cost of Ransom','Stealing', 'Unsafe Environment']

list_of_keywords_fin_tech = ['Mobile Money', 'Flutterwave', "Paystack", 'Mpesa', "Carbon", "PettySave", "Kuda", "MobileMoney", "Airtime", "USSD",
                             'Mpesa Transfer', 'Paystack Credit', 'Carbon MobileMoney Transfer', 'Kuda Transfer', 'Flutterwave wallet', 'Risevest' 
                             'Mobile Money Transfer', 'Mpesa MobileMoney', 'Flutterwave Cashless', 'Etransfer Africa', 'OPay', 'Palmpay', 'OneFi', '#Owo']

def fintech(all_list_of_places):
    ts = tweetsearch()
    for list_of_places in all_list_of_places:
        if list_of_places == list_of_places_one:
            file_name = 'KenyaTweetsFinTech.csv'
        elif list_of_places == list_of_places_two:
            file_name = 'NigeriaTweetsFinTech.csv'
        else:
            file_name = 'SouthAfricaTweetsFinTech.csv'
            
        for place in list_of_places:
            for item in additional:
                keywords = ['Fintech',place,item]
                final_keywords = " AND ".join(keywords)
                try:
                    df = ts.get_tweets(keyword=final_keywords, csvfile=file_name)
                    print(final_keywords)
                except tweepy.TweepError:
                    continue

        for keyword in list_of_keywords_fin_tech:
            for place in list_of_places:
                keywords = [keyword,place]
                final_keywords = " AND ".join(keywords)
                try:
                    ts = tweetsearch() 
                    df = ts.get_tweets(final_keywords, csvfile=file_name)
                    print(final_keywords)
                except tweepy.TweepError:
                    continue

                for item in additional:
                    keywords = [keyword,place,item]
                    final_keywords = " AND ".join(keywords)
                    try:
                        ts = tweetsearch() 
                        df = ts.get_tweets(final_keywords, csvfile=file_name)
                        print(final_keywords)
                    except tweepy.TweepError:
                        continue

# %%
fintech(all_list_of_places)
# Out:
# Fintech AND Kenya AND Mobilemoney
# Fintech AND Kenya AND Cashless
# Fintech AND Kenya AND Fintech
# Fintech AND Kenya AND Financial Technology
# Fintech AND Kenya AND StartUp Africa
# Fintech AND Nairobi AND Mobilemoney
# Fintech AND Nairobi AND Cashless
# Fintech AND Nairobi AND Fintech
# Fintech AND Nairobi AND Financial Technology
# Fintech AND Nairobi AND StartUp Africa
# Fintech AND Kisumu AND Mobilemoney
# Fintech AND Kisumu AND Cashless
# Fintech AND Kisumu AND Fintech
# Fintech AND Kisumu AND Financial Technology
# Fintech AND Kisumu AND StartUp Africa
# Fintech AND Mombasa AND Mobilemoney
# Fintech AND Mombasa AND Cashless
# Fintech AND Mombasa AND Fintech
# Fintech AND Mombasa AND Financial Technology
# Fintech AND Mombasa AND StartUp Africa
# Fintech AND Ghana AND Mobilemoney
# Fintech AND Ghana AND Cashless
# Fintech AND Ghana AND Fintech
# Fintech AND Ghana AND Financial Technology
# Fintech AND Ghana AND StartUp Africa
# Fintech AND Egypt AND Mobilemoney
# Fintech AND Egypt AND Cashless
# Fintech AND Egypt AND Fintech
# Fintech AND Egypt AND Financial Technology
# Fintech AND Egypt AND StartUp Africa
# Mobile Money AND Kenya
# Mobile Money AND Kenya AND Mobilemoney
# Mobile Money AND Kenya AND Cashless
# Mobile Money AND Kenya AND Fintech
# Mobile Money AND Kenya AND Financial Technology
# Mobile Money AND Kenya AND StartUp Africa
# Mobile Money AND Nairobi
# Mobile Money AND Nairobi AND Mobilemoney
# Mobile Money AND Nairobi AND Cashless
# Mobile Money AND Nairobi AND Fintech
# Mobile Money AND Nairobi AND Financial Technology
# Mobile Money AND Nairobi AND StartUp Africa
# Mobile Money AND Kisumu
# Mobile Money AND Kisumu AND Mobilemoney
# Mobile Money AND Kisumu AND Cashless
# Mobile Money AND Kisumu AND Fintech
# Mobile Money AND Kisumu AND Financial Technology
# Mobile Money AND Kisumu AND StartUp Africa
# Mobile Money AND Mombasa
# Mobile Money AND Mombasa AND Mobilemoney
# Mobile Money AND Mombasa AND Cashless
# Mobile Money AND Mombasa AND Fintech
# Mobile Money AND Mombasa AND Financial Technology
# Mobile Money AND Mombasa AND StartUp Africa
# Mobile Money AND Ghana
# Mobile Money AND Ghana AND Mobilemoney
# Mobile Money AND Ghana AND Cashless
# Mobile Money AND Ghana AND Fintech
# Mobile Money AND Ghana AND Financial Technology
# Mobile Money AND Ghana AND StartUp Africa
# Mobile Money AND Egypt
# Mobile Money AND Egypt AND Mobilemoney
# Mobile Money AND Egypt AND Cashless
# Mobile Money AND Egypt AND Fintech
# Mobile Money AND Egypt AND Financial Technology
# Mobile Money AND Egypt AND StartUp Africa
# Flutterwave AND Kenya
# Flutterwave AND Kenya AND Mobilemoney
# Flutterwave AND Kenya AND Cashless
# Flutterwave AND Kenya AND Fintech
# Flutterwave AND Kenya AND Financial Technology
# Flutterwave AND Kenya AND StartUp Africa
# Flutterwave AND Nairobi
# Flutterwave AND Nairobi AND Mobilemoney
# Flutterwave AND Nairobi AND Cashless
# Flutterwave AND Nairobi AND Fintech
# Flutterwave AND Nairobi AND Financial Technology
# Flutterwave AND Nairobi AND StartUp Africa
# Flutterwave AND Kisumu
# Flutterwave AND Kisumu AND Mobilemoney
# Flutterwave AND Kisumu AND Cashless
# Flutterwave AND Kisumu AND Fintech
# Flutterwave AND Kisumu AND Financial Technology
# Flutterwave AND Kisumu AND StartUp Africa
# Flutterwave AND Mombasa
# Flutterwave AND Mombasa AND Mobilemoney
# Flutterwave AND Mombasa AND Cashless
# Flutterwave AND Mombasa AND Fintech
# Flutterwave AND Mombasa AND Financial Technology
# Flutterwave AND Mombasa AND StartUp Africa
# Flutterwave AND Ghana
# Flutterwave AND Ghana AND Mobilemoney
# Flutterwave AND Ghana AND Cashless
# Flutterwave AND Ghana AND Fintech
# Flutterwave AND Ghana AND Financial Technology
# Flutterwave AND Ghana AND StartUp Africa
# Flutterwave AND Egypt
# Flutterwave AND Egypt AND Mobilemoney
# Flutterwave AND Egypt AND Cashless
# Flutterwave AND Egypt AND Fintech
# Flutterwave AND Egypt AND Financial Technology
# Flutterwave AND Egypt AND StartUp Africa
# Paystack AND Kenya
# Paystack AND Kenya AND Mobilemoney
# Paystack AND Kenya AND Cashless
# Paystack AND Kenya AND Fintech
# Paystack AND Kenya AND Financial Technology
# Paystack AND Kenya AND StartUp Africa
# Paystack AND Nairobi
# Paystack AND Nairobi AND Mobilemoney
# Paystack AND Nairobi AND Cashless
# Paystack AND Nairobi AND Fintech
# Paystack AND Nairobi AND Financial Technology
# Paystack AND Nairobi AND StartUp Africa
# Paystack AND Kisumu
# Paystack AND Kisumu AND Mobilemoney
# Paystack AND Kisumu AND Cashless
# Paystack AND Kisumu AND Fintech
# Paystack AND Kisumu AND Financial Technology
# Paystack AND Kisumu AND StartUp Africa
# Paystack AND Mombasa
# Paystack AND Mombasa AND Mobilemoney
# Paystack AND Mombasa AND Cashless
# Paystack AND Mombasa AND Fintech
# Paystack AND Mombasa AND Financial Technology
# Paystack AND Mombasa AND StartUp Africa
# Paystack AND Ghana
# Paystack AND Ghana AND Mobilemoney
# Paystack AND Ghana AND Cashless
# Paystack AND Ghana AND Fintech
# Paystack AND Ghana AND Financial Technology
# Paystack AND Ghana AND StartUp Africa
# Paystack AND Egypt
# Paystack AND Egypt AND Mobilemoney
# Paystack AND Egypt AND Cashless
# Paystack AND Egypt AND Fintech
# Paystack AND Egypt AND Financial Technology
# Paystack AND Egypt AND StartUp Africa
# Mpesa AND Kenya
# Mpesa AND Kenya AND Mobilemoney
# Mpesa AND Kenya AND Cashless
# Mpesa AND Kenya AND Fintech
# Mpesa AND Kenya AND Financial Technology
# Mpesa AND Kenya AND StartUp Africa
# Mpesa AND Nairobi
# Mpesa AND Nairobi AND Mobilemoney
# Mpesa AND Nairobi AND Cashless
# Mpesa AND Nairobi AND Fintech
# Mpesa AND Nairobi AND Financial Technology
# Mpesa AND Nairobi AND StartUp Africa
# Mpesa AND Kisumu
# Mpesa AND Kisumu AND Mobilemoney
# Mpesa AND Kisumu AND Cashless
# Mpesa AND Kisumu AND Fintech
# Mpesa AND Kisumu AND Financial Technology
# Mpesa AND Kisumu AND StartUp Africa
# Mpesa AND Mombasa
# Mpesa AND Mombasa AND Mobilemoney
# Mpesa AND Mombasa AND Cashless
# Mpesa AND Mombasa AND Fintech
# Mpesa AND Mombasa AND Financial Technology
# Mpesa AND Mombasa AND StartUp Africa
# Mpesa AND Ghana
# Mpesa AND Ghana AND Mobilemoney
# Mpesa AND Ghana AND Cashless
# Mpesa AND Ghana AND Fintech
# Mpesa AND Ghana AND Financial Technology
# Mpesa AND Ghana AND StartUp Africa
# Mpesa AND Egypt
# Mpesa AND Egypt AND Mobilemoney
# Mpesa AND Egypt AND Cashless
# Mpesa AND Egypt AND Fintech
# Mpesa AND Egypt AND Financial Technology
# Mpesa AND Egypt AND StartUp Africa
# Carbon AND Kenya
# Carbon AND Kenya AND Mobilemoney
# Carbon AND Kenya AND Cashless
# Carbon AND Kenya AND Fintech
# Carbon AND Kenya AND Financial Technology
# Carbon AND Kenya AND StartUp Africa
# Carbon AND Nairobi
# Carbon AND Nairobi AND Mobilemoney
# Carbon AND Nairobi AND Cashless
# Carbon AND Nairobi AND Fintech
# Carbon AND Nairobi AND Financial Technology
# Carbon AND Nairobi AND StartUp Africa
# Carbon AND Kisumu
# Carbon AND Kisumu AND Mobilemoney
# Carbon AND Kisumu AND Cashless
# Carbon AND Kisumu AND Fintech
# Carbon AND Kisumu AND Financial Technology
# Carbon AND Kisumu AND StartUp Africa
# Carbon AND Mombasa
# Carbon AND Mombasa AND Mobilemoney
# Carbon AND Mombasa AND Cashless
# Carbon AND Mombasa AND Fintech
# Carbon AND Mombasa AND Financial Technology
# Carbon AND Mombasa AND StartUp Africa
# Carbon AND Ghana
# Carbon AND Ghana AND Mobilemoney
# Carbon AND Ghana AND Cashless
# Carbon AND Ghana AND Fintech
# Carbon AND Ghana AND Financial Technology
# Carbon AND Ghana AND StartUp Africa
# Carbon AND Egypt
# Carbon AND Egypt AND Mobilemoney
# Carbon AND Egypt AND Cashless
# Carbon AND Egypt AND Fintech
# Carbon AND Egypt AND Financial Technology
# Carbon AND Egypt AND StartUp Africa
# PettySave AND Kenya
# PettySave AND Kenya AND Mobilemoney
# PettySave AND Kenya AND Cashless
# PettySave AND Kenya AND Fintech
# PettySave AND Kenya AND Financial Technology
# PettySave AND Kenya AND StartUp Africa
# PettySave AND Nairobi
# PettySave AND Nairobi AND Mobilemoney
# PettySave AND Nairobi AND Cashless
# PettySave AND Nairobi AND Fintech
# PettySave AND Nairobi AND Financial Technology
# PettySave AND Nairobi AND StartUp Africa
# PettySave AND Kisumu
# PettySave AND Kisumu AND Mobilemoney
# PettySave AND Kisumu AND Cashless
# PettySave AND Kisumu AND Fintech
# PettySave AND Kisumu AND Financial Technology
# PettySave AND Kisumu AND StartUp Africa
# PettySave AND Mombasa
# PettySave AND Mombasa AND Mobilemoney
# PettySave AND Mombasa AND Cashless
# PettySave AND Mombasa AND Fintech
# PettySave AND Mombasa AND Financial Technology
# PettySave AND Mombasa AND StartUp Africa
# PettySave AND Ghana
# PettySave AND Ghana AND Mobilemoney
# PettySave AND Ghana AND Cashless
# PettySave AND Ghana AND Fintech
# PettySave AND Ghana AND Financial Technology
# PettySave AND Ghana AND StartUp Africa
# PettySave AND Egypt
# PettySave AND Egypt AND Mobilemoney
# PettySave AND Egypt AND Cashless
# PettySave AND Egypt AND Fintech
# PettySave AND Egypt AND Financial Technology
# PettySave AND Egypt AND StartUp Africa
# Kuda AND Kenya
# Kuda AND Kenya AND Mobilemoney
# Kuda AND Kenya AND Cashless
# Kuda AND Kenya AND Fintech
# Kuda AND Kenya AND Financial Technology
# Kuda AND Kenya AND StartUp Africa
# Kuda AND Nairobi
# Kuda AND Nairobi AND Mobilemoney
# Kuda AND Nairobi AND Cashless
# Kuda AND Nairobi AND Fintech
# Kuda AND Nairobi AND Financial Technology
# Kuda AND Nairobi AND StartUp Africa
# Kuda AND Kisumu
# Kuda AND Kisumu AND Mobilemoney
# Kuda AND Kisumu AND Cashless
# Kuda AND Kisumu AND Fintech
# Kuda AND Kisumu AND Financial Technology
# Kuda AND Kisumu AND StartUp Africa
# Kuda AND Mombasa
# Kuda AND Mombasa AND Mobilemoney
# Kuda AND Mombasa AND Cashless
# Kuda AND Mombasa AND Fintech
# Kuda AND Mombasa AND Financial Technology
# Kuda AND Mombasa AND StartUp Africa
# Kuda AND Ghana
# Kuda AND Ghana AND Mobilemoney
# Kuda AND Ghana AND Cashless
# Kuda AND Ghana AND Fintech
# Kuda AND Ghana AND Financial Technology
# Kuda AND Ghana AND StartUp Africa
# Kuda AND Egypt
# Kuda AND Egypt AND Mobilemoney
# Kuda AND Egypt AND Cashless
# Kuda AND Egypt AND Fintech
# Kuda AND Egypt AND Financial Technology
# Kuda AND Egypt AND StartUp Africa
# MobileMoney AND Kenya
# MobileMoney AND Kenya AND Mobilemoney
# MobileMoney AND Kenya AND Cashless
# MobileMoney AND Kenya AND Fintech
# MobileMoney AND Kenya AND Financial Technology
# MobileMoney AND Kenya AND StartUp Africa
# MobileMoney AND Nairobi
# MobileMoney AND Nairobi AND Mobilemoney
# MobileMoney AND Nairobi AND Cashless
# MobileMoney AND Nairobi AND Fintech
# MobileMoney AND Nairobi AND Financial Technology
# MobileMoney AND Nairobi AND StartUp Africa
# MobileMoney AND Kisumu
# MobileMoney AND Kisumu AND Mobilemoney
# MobileMoney AND Kisumu AND Cashless
# MobileMoney AND Kisumu AND Fintech
# MobileMoney AND Kisumu AND Financial Technology
# MobileMoney AND Kisumu AND StartUp Africa
# MobileMoney AND Mombasa
# MobileMoney AND Mombasa AND Mobilemoney
# MobileMoney AND Mombasa AND Cashless

# %%
a = pd.read_csv('KenyaTweetsFinTech.csv')
a
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-15-9860137a8eb7> in <module>
# ----> 1 a = pd.read_csv('SouthAfricaTweetsFinTech.csv')
#       2 a
#
# /workspace/.conda/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# /workspace/.conda/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# /workspace/.conda/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1184     def read(self, nrows=None):
#    1185         nrows = _validate_integer("nrows", nrows)
# -> 1186         ret = self._engine.read(nrows)
#    1187
#    1188         # May alter columns / col_dict
#
# /workspace/.conda/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2143     def read(self, nrows=None):
#    2144         try:
# -> 2145             data = self._reader.read(nrows)
#    2146         except StopIteration:
#    2147             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 17 fields in line 3, saw 20

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener

class MyListener(StreamListener):
    
    def on_data(self, data):
        try:
            with open('google.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print(f"Error on_data: {e}")
            
        return True
    
    def on_error(self, status):
        print(status)
        return True
    
twitter_stream = Stream(ts.auth, MyListener())
twitter_stream.filter(track=['googleI/O', 'google', 'bigtech', 'Bigtech', 'GoogleIO', 'googlechrome', 
                             'googledevs', 'android', 'madebygoogle)'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /workspace/.conda/lib/python3.8/http/client.py in _get_chunk_left(self)
#     550             try:
# --> 551                 chunk_left = self._read_next_chunk_size()
#     552             except ValueError:
#
# /workspace/.conda/lib/python3.8/http/client.py in _read_next_chunk_size(self)
#     517         try:
# --> 518             return int(line, 16)
#     519         except ValueError:
#
# ValueError: invalid literal for int() with base 16: b''
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# /workspace/.conda/lib/python3.8/http/client.py in _readinto_chunked(self, b)
#     582             while True:
# --> 583                 chunk_left = self._get_chunk_left()
#     584                 if chunk_left is None:
#
# /workspace/.conda/lib/python3.8/http/client.py in _get_chunk_left(self)
#     552             except ValueError:
# --> 553                 raise IncompleteRead(b'')
#     554             if chunk_left == 0:
#
# IncompleteRead: IncompleteRead(0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# /workspace/.conda/lib/python3.8/site-packages/urllib3/response.py in _error_catcher(self)
#     435             try:
# --> 436                 yield
#     437
#
# /workspace/.conda/lib/python3.8/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     517                 cache_content = False
# --> 518                 data = self._fp.read(amt) if not fp_closed else b""
#     519                 if (
#
# /workspace/.conda/lib/python3.8/http/client.py in read(self, amt)
#     453             b = bytearray(amt)
# --> 454             n = self.readinto(b)
#     455             return memoryview(b)[:n].tobytes()
#
# /workspace/.conda/lib/python3.8/http/client.py in readinto(self, b)
#     487         if self.chunked:
# --> 488             return self._readinto_chunked(b)
#     489
#
# /workspace/.conda/lib/python3.8/http/client.py in _readinto_chunked(self, b)
#     598         except IncompleteRead:
# --> 599             raise IncompleteRead(bytes(b[0:total_bytes]))
#     600
#
# IncompleteRead: IncompleteRead(0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-132-bb22c60e59ab> in <module>
#      19
#      20 twitter_stream = Stream(ts.auth, MyListener())
# ---> 21 twitter_stream.filter(track=['googleI/O', 'google', 'bigtech', 'Bigtech', 'GoogleIO', 'googlechrome',
#      22                              'googledevs', 'android', 'madebygoogle)'])
#
# /workspace/.conda/lib/python3.8/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# /workspace/.conda/lib/python3.8/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# /workspace/.conda/lib/python3.8/site-packages/tweepy/streaming.py in _run(self)
#     318             # call a handler first so that the exception can be logged.
#     319             self.listener.on_exception(exc_info[1])
# --> 320             six.reraise(*exc_info)
#     321
#     322     def _data(self, data):
#
# /workspace/.conda/lib/python3.8/site-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# /workspace/.conda/lib/python3.8/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# /workspace/.conda/lib/python3.8/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# /workspace/.conda/lib/python3.8/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# /workspace/.conda/lib/python3.8/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     538                         # raised during streaming, so all calls with incorrect
#     539                         # Content-Length are caught.
# --> 540                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     541
#     542         if data:
#
# /workspace/.conda/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     129                 value = type()
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#     133                 # Suppress StopIteration *unless* it's the same exception that
#
# /workspace/.conda/lib/python3.8/site-packages/urllib3/response.py in _error_catcher(self)
#     452             except (HTTPException, SocketError) as e:
#     453                 # This includes IncompleteRead.
# --> 454                 raise ProtocolError("Connection broken: %r" % e, e)
#     455
#     456             # If no exception is thrown, we should avoid cleaning up
#
# ProtocolError: ('Connection broken: IncompleteRead(0 bytes read)', IncompleteRead(0 bytes read))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dd = pd.read_csv('insecurtyTweets.csv')

dd.shape
# Out:
# (252371, 17)

# %%
d = dd.drop_duplicates()
d.shape
# Out:
# (106493, 17)

# %%
d['original_text'].sample(20).values
# Out:
# array(['RT @lollypeezle: There’s a new trend of robbery in Lagos now. Someone will wave your car down inside traffic that one of your back doors is…',
#        'RT @ShehuSani: Those who are openly or secretly recruiting and paying Thugs to intimidate and attack peaceful Labour protesters in Kaduna,s…',
#        'RT @MaziNnamdiKanu: Pray tonight for #ESN; the brave defenders of Biafraland. They are our own version of the IRON DOME; protecting the lan…',
#        'RT @MaziNnamdiKanu: Pray tonight for #ESN; the brave defenders of Biafraland. They are our own version of the IRON DOME; protecting the lan…',
#        '@Omojuwa National trajedy to Nigeria but a Major win for Boko Haram, ISWAP, Bandits and "Killer Herdmen".\nGradually, Nigerian Military\'s Capacity to combat these criminal elements is being degraded one blow at a time.',
#        'RT @AyannaPressley: Organizers from Minneapolis to Boston to Lagos mobilized to demand accountability. But a person’s murder should not req…',
#        'RT @savndaniel: Northerners have ruled Nigeria more than every other region. Apart from Yaradua, every northern leader to grace Aso Rock -…',
#        'RT @NigeriaStories: Today we remember Dora Akunyili, who died in 2014, she lost her sister, who was given fake insulin for diabetes. This w…',
#        '@SKefason Do you know the grievances of the unknown gunmen? It follows the same pattern. The Police will mount road blocks and still the kidnappers, bandits and armed herdsmen will still operate freely. Is there any need for Police in our present day Nigeria?',
#        "RT @DavidHundeyin: If Nigeria somehow escapes Yugoslavia's fate - which looks increasingly less likely with every passing month - the Land…",
#        'RT @DrOlufunmilayo: When southerners go up north,\nThey buy land, they rent shops,\nThen use it for business.\n\nBut when killer herdsmen, larg…',
#        "RT @ogheneisaiah: So there's a new mode of robbery on the highways these days. Yesterday night, just before Ovia river along Benin-Lagos ex…",
#        "RT @Ma3Route: 08:05 Kenya's roadside motor vehicle parts lifters are on another level. This thief was caught red-handed stealing side-mirro…",
#        'RT @SammieLaolu: If you reside in LAGOS (especially Island) and you have those Estate Security Stickers on your car, pls kindly remove them…',
#        'The wanton theft of public resources in Kenya is astonishing.This is just one project out of a possible 30+ in a financial year .uhuru out https://t.co/rwJgfrfauS',
#        "RT @Zuby215: People don't really care about bad governance. They only worry that their favorite politician, or potential benefactor doesn't…",
#        'RT @DejiAdesogan: So much energy, bold, brilliant &amp;  balanced. It’s a monumental loss to the Nigerian Army, AFN &amp; Nigeria at large\n\nWe that…',
#        'RT @Carolynkimbrlyy: Nigeria Military Helicopters are in Arondizugo Imo State killing innocent people now. #Biafran_Silent_Genocide',
#        'RT @DailyPostNGR: Rescue Leah Sharibu, others before criminalizing ransom payment - Ogun Oba, Eselu writes Senate - Daily Post Nigeria http…',
#        'RT @EbituPromise: Northern Youths Blame Insecurity in Nigeria on Jonathan | #EbituBlog https://t.co/Nz0tJBIT2U'],
#       dtype=object)

# %%
plt.style.use('fivethirtyeight')

# %%
d.groupby('original_author')['original_author'].count().sort_values(ascending=False)[:10]
# Out:
# original_author
# Sasha03545351      121
# Johniky5            98
# Chidieb51762406     96
# Ejikech11438647     87
# SaveIpob            84
# NwaGodP5            83
# Okeybiafra5         74
# PillarSpace         73
# COCOPACOPIACO1      72
# DailyPostNGR        69
# Name: original_author, dtype: int64

# %%
locs = d['place_coord_boundaries'].value_counts()
locs[locs > 30]
# Out:
# Lagos, Nigeria     8416
# Nigeria            6991
# Abuja, Nigeria     2361
# Lagos              1599
# Nairobi, Kenya     1041
#                    ...
# Nowhere              31
# Eastern Nigeria      31
# Moon                 31
# Bahamas              31
# Pluto                31
# Name: place_coord_boundaries, Length: 183, dtype: int64

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent='twitter-analysis-cl')

locs = list(locs.index)

# %%
geolocated = list(map(lambda x: [x, geolocator.geocode(x)[1] if geolocator.geocode(x) else None], locs))

geolocated = pd.DataFrame(geolocated)
geolocated.columns = ['location', 'latlong']

geolocated['lat'] = geolocated.latlong.apply(lambda x: x[0])
geolocated['lon'] = geolocated.latlong.apply(lambda x: x[1])
geolocated.drop('latlong', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /workspace/.conda/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /workspace/.conda/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /workspace/.conda/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# /workspace/.conda/lib/python3.8/http/client.py in getresponse(self)
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#
# /workspace/.conda/lib/python3.8/http/client.py in begin(self)
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#
# /workspace/.conda/lib/python3.8/http/client.py in _read_status(self)
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#
# /workspace/.conda/lib/python3.8/socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# /workspace/.conda/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# /workspace/.conda/lib/python3.8/ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# /workspace/.conda/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# /workspace/.conda/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     429             raise
#
# /workspace/.conda/lib/python3.8/site-packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     334         if isinstance(err, SocketTimeout):
# --> 335             raise ReadTimeoutError(
#     336                 self, url, "Read timed out. (read timeout=%s)" % timeout_value
#
# ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /workspace/.conda/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /workspace/.conda/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     753             )
# --> 754             return self.urlopen(
#     755                 method,
#
# /workspace/.conda/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     753             )
# --> 754             return self.urlopen(
#     755                 method,
#
# /workspace/.conda/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /workspace/.conda/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     438         if new_retry.is_exhausted():
# --> 439             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     440
#
# MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=127.0.0.1&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/geopy/adapters.py in _request(self, url, timeout, headers)
#     386         try:
# --> 387             resp = self.session.get(url, timeout=timeout, headers=headers)
#     388         except Exception as error:
#
# /workspace/.conda/lib/python3.8/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#
# /workspace/.conda/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#
# /workspace/.conda/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#
# /workspace/.conda/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=127.0.0.1&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# <ipython-input-42-3453583b2680> in <module>
# ----> 1 geolocated = list(map(lambda x: [x, geolocator.geocode(x)[1] if geolocator.geocode(x) else None], locs))
#       2
#       3 geolocated = pd.DataFrame(geolocated)
#       4 geolocated.columns = ['location', 'latlong']
#       5
#
# <ipython-input-42-3453583b2680> in <lambda>(x)
# ----> 1 geolocated = list(map(lambda x: [x, geolocator.geocode(x)[1] if geolocator.geocode(x) else None], locs))
#       2
#       3 geolocated = pd.DataFrame(geolocated)
#       4 geolocated.columns = ['location', 'latlong']
#       5
#
# ~/.local/lib/python3.8/site-packages/geopy/geocoders/nominatim.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296         callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 297         return self._call_geocoder(url, callback, timeout=timeout)
#     298
#     299     def reverse(
#
# ~/.local/lib/python3.8/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, callback, timeout, is_json, headers)
#     358         try:
#     359             if is_json:
# --> 360                 result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     361             else:
#     362                 result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# ~/.local/lib/python3.8/site-packages/geopy/adapters.py in get_json(self, url, timeout, headers)
#     375
#     376     def get_json(self, url, *, timeout, headers):
# --> 377         resp = self._request(url, timeout=timeout, headers=headers)
#     378         try:
#     379             return resp.json()
#
# ~/.local/lib/python3.8/site-packages/geopy/adapters.py in _request(self, url, timeout, headers)
#     397                     raise GeocoderServiceError(message)
#     398                 else:
# --> 399                     raise GeocoderUnavailable(message)
#     400             elif isinstance(error, requests.Timeout):
#     401                 raise GeocoderTimedOut("Service timed out")
#
# GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=127.0.0.1&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))

# %%
geolocated.head(10)

# %%
mapdata = pd.merge(d, geolocated, how='inner', left_on='place_coord_boundaries', right_on='location')

locations = mapdata.groupby(by=['location', 'lat', 'lon']).count()['created_at'].sort_values(ascending=False)

# %%
locations.head(10)

# %%
plt.rcParams.update({'font.size': 20})
plt.rcParams['figure.figsize'] = (20, 10)

# %% [markdown]
# ## Class Automation

# %%
class Automation:
    """
    The PEP8 Standard AMAZING!!!
    """
    def __init__(self):
        print('Automation in Action...!!!')

    def Clean_Tweets(self, df):
        # drop na in clean tweets column
        a = df[df['retweet_count'] == 'retweet_count' ].index
        df.drop(a , inplace=True)
        # dropduplicates and drop duplicates in clean tweets
        df = df.drop_duplicates().drop_duplicates(subset='clean_text')
        # convert int column appropriately
        df = df[df['polarity'] != 'polarity']
        # convert the created_at column to a datetime object
        df['created_at'] = pd.to_datetime(df['created_at'], errors='coerce')
        df['created_at'] = df['created_at'].dt.strftime('%Y-%m-%d')
        df = df[df['created_at'] >= '2019-01-01' ]
        # convert int column appropriately
        df['polarity'] = pd.to_numeric(df['polarity'], errors='coerce')
        df['subjectivity'] = pd.to_numeric(df['subjectivity'], errors='coerce')
        df['retweet_count'] = pd.to_numeric(df['retweet_count'], errors='coerce')
        df['favorite_count'] = pd.to_numeric(df['favorite_count'], errors='coerce')
        return df

    def Time_Trend(self, df, city,x):
        ax = df.groupby('created_at')[['retweet_count', 'favorite_count', 'number']].sum().plot(figsize=(20,8))
        plt.title(f'Trend of likes and retweets for {city}', size=20)
        plt.axvline(x=x,color='gray',linestyle='--')
        plt.ylabel('Frequency', fontsize=14)
        plt.xlabel('Time', fontsize=14)
        plt.xticks(rotation=45)
        plt.show()
        
        
    def Draw_Wordcloud(self, tweets_series, description):
        # word cloud visualization
        allWords = ' '.join([twts for twts in tweets_series])
        wordCloud = WordCloud(width=500, height=300, random_state=21, max_font_size=110, stopwords=STOPWORDS, collocations=False).generate(allWords)
        plt.figure(figsize=(15, 12))
        plt.imshow(wordCloud, interpolation="bilinear")
        plt.axis('off')
        plt.title(f'Most used words describing {description}', size=20)
        plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS

bigsting = d['original_text'].apply(lambda x: ' '.join(x)).str.cat(sep=' ')

# %%
auto = Automation()
# Out:
# Automation in Action...!!!

# %%
df = auto.Clean_Tweets(d)

# %%
df.shape
# Out:
# (13330, 17)

# %%
auto.Draw_Wordcloud(df['original_text'], 'Insecurity In Africa')

# %%
import re
hashtags = df['original_text'].apply(lambda x: pd.value_counts(re.findall('(#\w+)', x.lower() ))).sum(axis=0).to_frame()\
        .reset_index().sort_values(by=0, ascending=False)

hashtags.columns=['hashtags', 'occurences']

hashtags.head(10)
# Out:
#          hashtags  occurences
# 1065     #nigeria       543.0
# 492      #endsars       103.0
# 776   #insecurity        89.0
# 1048        #news        79.0
# 1497   #terrorism        69.0
# 178   #biafraexit        56.0
# 341   #corruption        54.0
# 212    #bokoharam        46.0
# 876        #kenya        45.0
# 861       #kaduna        41.0

# %%
hashtags[:10].plot.bar(x='hashtags', y='occurences', figsize=(13, 7))
plt.tight_layout()
plt.grid(False)
plt.suptitle("Top 10 Hashtags describing Insecurity", size=20);

# %%
# user mention
plt.grid(False)
plt.tight_layout()
plt.suptitle("Top 10 mentioned users", size=20)
df['original_text'].str.findall('(@[A-Za-z0-9]+)').apply(lambda x: pd.value_counts(x)).sum(axis=0).sort_values(ascending=False)[:10].plot.bar(figsize=(13,6))
# Out:
# <AxesSubplot:>

# %%
df.groupby(['hashtags', 'original_author']).\
            agg({'retweet_count': 'mean', 'favorite_count': 'mean'}).sort_values(by='retweet_count', ascending=False)[:10]
# Out:
#                                                                     retweet_count  \
# hashtags                                           original_author
# Nigeria                                            1NellyNelle            66266.0
#                                                    Nestet3                 9305.0
# ENDNIGERIANOWSAVELIVES, ENDNIGERIANOWSAVELIVES,... benjaffy1               5947.0
# ESN, Fulani                                        MaziNnamdiKanu          5947.0
#                                                    MrC_ce                  5947.0
# ESN                                                frank_thamos            5947.0
#                                                    Ifeanyinwora2           5947.0
# BiafraExit                                         NwabiafraO              5171.0
# Buhari                                             BernardUdoye            4847.0
# Fulani                                             AmBiafran               4741.0
#
#                                                                     favorite_count
# hashtags                                           original_author
# Nigeria                                            1NellyNelle                 0.0
#                                                    Nestet3                     0.0
# ENDNIGERIANOWSAVELIVES, ENDNIGERIANOWSAVELIVES,... benjaffy1                   0.0
# ESN, Fulani                                        MaziNnamdiKanu           8472.0
#                                                    MrC_ce                      0.0
# ESN                                                frank_thamos                0.0
#                                                    Ifeanyinwora2               0.0
# BiafraExit                                         NwabiafraO                  0.0
# Buhari                                             BernardUdoye                0.0
# Fulani                                             AmBiafran                   0.0

# %%
tt = df.groupby(['original_author'])['hashtags'].value_counts().sort_values(ascending=False)

tt = pd.DataFrame(tt)
tt.columns = ['counts_hashtags']
tt.reset_index(inplace=True)
tt.columns
# Out:
# Index(['original_author', 'hashtags', 'counts_hashtags'], dtype='object')

# %%
tt=tt[tt['hashtags'] != 'NotCommon']

tt.groupby(['hashtags', 'original_author']).sum().sort_values(by='counts_hashtags', ascending=False)
# Out:
#                                     counts_hashtags
# hashtags           original_author
# Nigeria, News      PlatinumPostNg                26
# Nigeria, Security  riskmap_                      10
# AlQuds, AlAqsa     stpfakenews                    7
# Nigeria, News      Infotrustng                    7
# Nigeria            HermattanLLC                   6
# ...                                             ...
# HealNigeriaNow     IamDouggy                      1
# HeadsUp            Yeribabaa                      1
#                    Oniyabba                       1
# HarmReduction, HIV SWOP_Kenya                     1
# zoo                RetweetingGood                 1
#
# [1838 rows x 1 columns]

# %%
df['place_coord_boundaries'].value_counts()
# Out:
# Nigeria                          1251
# Lagos, Nigeria                   1098
# Abuja, Nigeria                    377
# Nairobi, Kenya                    328
# Lagos                             207
#                                  ...
# Lagos State. Nigeria                1
# port Harcourt , Nigeria             1
# Malmö, Sverige                      1
# Nairobi•Norwich •Albuquerque•       1
# Somewhere in between.               1
# Name: place_coord_boundaries, Length: 2776, dtype: int64

# %%
df.columns
# Out:
# Index(['timestamp', 'created_at', 'source', 'original_text', 'clean_text',
#        'sentiment', 'polarity', 'subjectivity', 'lang', 'favorite_count',
#        'retweet_count', 'original_author', 'possibly_sensitive', 'hashtags',
#        'user_mentions', 'place', 'place_coord_boundaries'],
#       dtype='object')

# %%
words = df['original_text'].dropna().apply(lambda x: pd.value_counts(re.findall('([\s]\w+[\s])',' '.join(x)))).sum(axis=0).to_frame().reset_index().sort_values(by=0,
    ascending=False)
words.columns = ['word', 'occurences']

words.head(10)
# Out:
#    word  occurences
# 2    t      99891.0
# 17   e      95126.0
# 9    a      90722.0
# 3    i      75794.0
# 1    r      72562.0
# 0    s      71260.0
# 36   n      57760.0
# 7    o      57270.0
# 6    l      41092.0
# 5    c      40617.0

# %%
from nltk import bigrams

bigram_series = pd.Series(word for sublist in df['original_text'].dropna().apply(lambda x: [i for i in bigrams(x)]).tolist())

# %%
df.to_csv('insecurtyTweets.csv', index=False)

# %% [markdown]
# ## Fintech EDA

# %%
fin = pd.read_csv('twitter_data2.csv')
fin.head()
# Out:
#                    timestamp                      created_at  \
# 0  2021-05-19 05:43:24+00:00  Wed May 19 05:43:24 +0000 2021
# 1  2021-05-20 19:33:33+00:00  Thu May 20 19:33:33 +0000 2021
# 2  2021-05-20 19:47:48+00:00  Thu May 20 19:47:48 +0000 2021
# 3  2021-05-22 07:50:57+00:00  Sat May 22 07:50:57 +0000 2021
# 4                  timestamp                      created_at
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4                                             source
#
#                                        original_text  \
# 0  @CosmicEnergy_ I'm in the process of my accomp...
# 1  @kotex_sa #changethetune I'm me, best me, I'm ...
# 2  #ResearcherInAfrica I'm doing PhD research in ...
# 3  It's been tough trying to find funding for my ...
# 4                                      original_text
#
#                                           clean_text  \
# 0                        I 'm process accomplishment
# 1           I 'm best I 'm free every woman see also
# 2  I 'm PhD research student mental health Higher...
# 3  It 's tough trying find funding Phd research I...
# 4                                         clean_text
#
#                                            sentiment             polarity  \
# 0          Sentiment(polarity=0.0, subjectivity=0.0)                  0.0
# 1         Sentiment(polarity=0.7, subjectivity=0.55)                  0.7
# 2       Sentiment(polarity=0.075, subjectivity=0.35)                0.075
# 3  Sentiment(polarity=-0.1222222222222222, subjec...  -0.1222222222222222
# 4                                          sentiment             polarity
#
#          subjectivity  lang  favorite_count  retweet_count  original_author  \
# 0                 0.0    en               0              0        CandiceMe
# 1                0.55    en               0              0        CandiceMe
# 2                0.35    en              21              6        CandiceMe
# 3  0.5583333333333333    en               0              0        CandiceMe
# 4        subjectivity  lang  favorite_count  retweet_count  original_author
#
#    possibly_sensitive                                           hashtags  \
# 0                 NaN                                                NaN
# 1                 NaN                                      changethetune
# 2                 NaN                                 ResearcherInAfrica
# 3                 NaN  research, AcademicTwitter, mentalhealth, Acade...
# 4  possibly_sensitive                                           hashtags
#
#    user_mentions  place   place_coord_boundaries
# 0  CosmicEnergy_    NaN  Bellville, South Africa
# 1       kotex_sa    NaN  Bellville, South Africa
# 2            NaN    NaN  Bellville, South Africa
# 3            NaN    NaN  Bellville, South Africa
# 4  user_mentions  place   place_coord_boundaries
